# %% [markdown]
# # Exploratory Data Analysis (EDA) of Processed Amharic Telegram Messages
#
# This notebook performs a quick EDA on the processed Amharic text data. For each channel, it:
# - Prints the total number of messages and the average number of tokens per message.
# - Randomly samples and displays 5 messages, showing:
#     - The original text
#     - The cleaned text
#     - The token list
#
# This helps you check the quality of your preprocessing and tokenization before moving on to labeling or modeling.

# %%
import os
import json
import random
from glob import glob

SAMPLES_PER_CHANNEL = 5

def eda_channel(channel, processed_dir):
    in_dir = os.path.join(processed_dir, channel)
    files = glob(os.path.join(in_dir, 'msg_*.json'))
    if not files:
        print(f"No processed messages found for channel: {channel}")
        return
    print(f"\n=== Channel: {channel} ===")
    # Print basic stats
    num_msgs = len(files)
    token_counts = []
    for file_path in files:
        with open(file_path, 'r', encoding='utf-8') as f:
            msg = json.load(f)
        token_counts.append(len(msg.get('tokens', [])))
    print(f"Total messages: {num_msgs}")
    print(f"Average tokens per message: {sum(token_counts)/num_msgs:.2f}")
    # Show random samples
    sample_files = random.sample(files, min(SAMPLES_PER_CHANNEL, num_msgs))
    for file_path in sample_files:
        with open(file_path, 'r', encoding='utf-8') as f:
            msg = json.load(f)
        print("\n--- Sample Message ---")
        print(f"Original: {msg.get('text', '')}")
        print(f"Cleaned:  {msg.get('cleaned_text', '')}")
        print(f"Tokens:   {msg.get('tokens', [])}")

project_root = os.path.dirname(os.path.dirname(os.path.abspath('')))
processed_dir = os.path.join('..', 'data', 'processed', 'text')
channels = [d for d in os.listdir(processed_dir) if os.path.isdir(os.path.join(processed_dir, d))]
for channel in channels:
    eda_channel(channel, processed_dir)
# Out:
# === Channel: forfreemarket ===
# Total messages: 242
# Average tokens per message: 37.50
#
# --- Sample Message ---
# Original: 💥.. Hair Steamer (የፀጉር እስቲም)
#
# ▶️ የሚታጠብ
#
# ▶️ ላጠቃቀም ቀላል
#
# ▶️ ምቾትን የሚያላብስ
#
#
#         💦 ዋጋ፦ ✅ 800 ብር
#
#
# 🔔ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
#
#
# 1️⃣.📌ፒያሳ ጣይቱ ሆቴል ጊቢ ውስጥ ቢሮ ቁ04
#
# 2️⃣.📌መገናኛ መተባበር ሕንፃ 3ኛ ፎቅ ቢሮ ቁ316
#
#
# ለማዘዝ እነዚን ቁጥሮች ይጠቀሙ🔽
#                                     📲 0911100302
#                                           0911887579
# 🔖
# 💬በቴሌግራም ለማዘዝ ➡️ @Akdat
#
# ቤተሰብ ይሁኑ🔽
# https://t.me/forfreemarket
#
# 🇪🇹 4FREE MARKET 🇪🇹
# Cleaned:  .. የፀጉር እስቲም የሚታጠብ ላጠቃቀም ቀላል ምቾትን የሚያላብስ ዋጋ 800 ብር ውስን ፍሬ ነው ያለው .ፒያሳ ጣይቱ ሆቴል ጊቢ ውስጥ ቢሮ ቁ04 .መገናኛ መተባበር ሕንፃ 3ኛ ፎቅ ቢሮ ቁ316 ለማዘዝ እነዚን ቁጥሮች ይጠቀሙ 0911100302 0911887579 በቴሌግራም ለማዘዝ ቤተሰብ ይሁኑ 4
# Tokens:   ['..', 'የፀጉር', 'እስቲም', 'የሚታጠብ', 'ላጠቃቀም', 'ቀላል', 'ምቾትን', 'የሚያላብስ', 'ዋጋ', '800', 'ብር', 'ውስን', 'ፍሬ', 'ነው', 'ያለው', '.ፒያሳ', 'ጣይቱ', 'ሆቴል', 'ጊቢ', 'ውስጥ', 'ቢሮ', 'ቁ04', '.መገናኛ', 'መተባበር', 'ሕንፃ', '3ኛ', 'ፎቅ', 'ቢሮ', 'ቁ316', 'ለማዘዝ', 'እነዚን', 'ቁጥሮች', 'ይጠቀሙ', '0911100302', '0911887579', 'በቴሌግራም', 'ለማዘዝ', 'ቤተሰብ', 'ይሁኑ', '4']
#
# --- Sample Message ---
# Original: 💥SUN 5 Nail Dryer
# Cleaned:  5
# Tokens:   ['5']
#
# --- Sample Message ---
# Original: ✅ Rechargeable Clothes Lint Remover
#
# 🍀
# 👉 Electric Lint Remover for most Types of Clothes
#
# 💥Specification:
# ⚡️Battery capacity: 1200mAh
# ⚡️Charging time: 3 to 4 hours
# ⚡️Using time: 1 hour
# ⚡️Charging display: red light when charging, and the light remains the same color when full, it can be charge enough for 3-4 hours hrs
#
#              💦 ዋጋ፦ ✅ 900 ብር
#
#    አድራሻ👉
# 1️⃣.📌ፒያሳ ጣይቱ ሆቴል ጊቢ ውስጥ ቢሮ ቁ04
#
# 2️⃣.📌መገናኛ መተባበር ሕንፃ 3ኛ ፎቅ ቢሮ ቁ316
#
#
# ለማዘዝ እነዚን ቁጥሮች ይጠቀሙ🔽
#                                     📲 0911100302
#                                           0911887579
# 🔖
# 💬በቴሌግራም ለማዘዝ ➡️ @Akdat
#
# ቤተሰብ ይሁኑ🔽
# https://t.me/forfreemarket
#
# 🇪🇹 4FREE MARKET 🇪🇹
# Cleaned:  1200 3 4 1 , , 34 ዋጋ 900 ብር አድራሻ .ፒያሳ ጣይቱ ሆቴል ጊቢ ውስጥ ቢሮ ቁ04 .መገናኛ መተባበር ሕንፃ 3ኛ ፎቅ ቢሮ ቁ316 ለማዘዝ እነዚን ቁጥሮች ይጠቀሙ 0911100302 0911887579 በቴሌግራም ለማዘዝ ቤተሰብ ይሁኑ 4
# Tokens:   ['1200', '3', '4', '1', ',', ',', '34', 'ዋጋ', '900', 'ብር', 'አድራሻ', '.ፒያሳ', 'ጣይቱ', 'ሆቴል', 'ጊቢ', 'ውስጥ', 'ቢሮ', 'ቁ04', '.መገናኛ', 'መተባበር', 'ሕንፃ', '3ኛ', 'ፎቅ', 'ቢሮ', 'ቁ316', 'ለማዘዝ', 'እነዚን', 'ቁጥሮች', 'ይጠቀሙ', '0911100302', '0911887579', 'በቴሌግራም', 'ለማዘዝ', 'ቤተሰብ', 'ይሁኑ', '4']
#
# --- Sample Message ---
# Original: 💥.......ግላስ የውሀ ማቅረቢያ........💥
#
#
# 👉ውብ እና ማራኪ
# 👉እስከ 400°c ሙቀት መቋቋም ስለሚችል ስቶቭ ላይ መጣድ የሚችል
# 👉ከፍተኛ ጥራት ያለው 💯
#
# 💦 ዋጋ፦✅ 1,500 ብር
#
#
# አድራሻ👉
# 1️⃣.📌ፒያሳ ጣይቱ ሆቴል ጊቢ ውስጥ ቢሮ ቁ04
#
# 2️⃣.📌መገናኛ መተባበር ሕንፃ 3ኛ ፎቅ ቢሮ ቁ316
#
#
# ለማዘዝ እነዚን ቁጥሮች ይጠቀሙ🔽
#                                     📲 0911100302
#                                           0911887579
# 🔖
# 💬በቴሌግራም ለማዘዝ ➡️ @Akdat
#
# ቤተሰብ ይሁኑ🔽
# https://t.me/forfreemarket
#
# 🇪🇹 4FREE MARKET 🇪🇹
# Cleaned:  ግላስ የውሀ ማቅረቢያ ውብ እና ማራኪ እስከ 400 ሙቀት መቋቋም ስለሚችል ስቶቭ ላይ መጣድ የሚችል ከፍተኛ ጥራት ያለው ዋጋ 1,500 ብር አድራሻ .ፒያሳ ጣይቱ ሆቴል ጊቢ ውስጥ ቢሮ ቁ04 .መገናኛ መተባበር ሕንፃ 3ኛ ፎቅ ቢሮ ቁ316 ለማዘዝ እነዚን ቁጥሮች ይጠቀሙ 0911100302 0911887579 በቴሌግራም ለማዘዝ ቤተሰብ ይሁኑ 4
# Tokens:   ['ግላስ', 'የውሀ', 'ማቅረቢያ', 'ውብ', 'እና', 'ማራኪ', 'እስከ', '400', 'ሙቀት', 'መቋቋም', 'ስለሚችል', 'ስቶቭ', 'ላይ', 'መጣድ', 'የሚችል', 'ከፍተኛ', 'ጥራት', 'ያለው', 'ዋጋ', '1,500', 'ብር', 'አድራሻ', '.ፒያሳ', 'ጣይቱ', 'ሆቴል', 'ጊቢ', 'ውስጥ', 'ቢሮ', 'ቁ04', '.መገናኛ', 'መተባበር', 'ሕንፃ', '3ኛ', 'ፎቅ', 'ቢሮ', 'ቁ316', 'ለማዘዝ', 'እነዚን', 'ቁጥሮች', 'ይጠቀሙ', '0911100302', '0911887579', 'በቴሌግራም', 'ለማዘዝ', 'ቤተሰብ', 'ይሁኑ', '4']
#
# --- Sample Message ---
# Original: 💥.....Onestep Hair Dryer & Styler 💥
#
# ✅  3 ጥቅሞችን አንድ ላይ የያዘ
#      ♦️እያደረቀ የሚያበጥር
#
#    ✔️ 1 ዕቃ 3 ጥቅም
#                ❶ ማድረቂያ ፣
#                ❷ፔስትራ(ሰትሪት መስሪያ)፣
#                 ❸ከርል መስርያ
# ✔️3 የሙቀት መጠን  ያለው ለጠንካራ ለመካከለኛ ለሉጫ ፀጉርም ሚሆን
# ✔️ጊዜ ቆጣቢ ፀጉርን በእሳት ከመጐዳት የሚከላከል
# ✔️ለልጆችም ለአዎቂ ተስማሚ የሆነ
# ✔️ ጥራቱ አስተማማኝ እና ለአጠቃቀም ቀላል
# ✔️በቤትዎ እና ለፀጉር ቤት ተመራጭ
#
#
# 💦 ዋጋ፦ ✅ 1,600 ብር
#
#
# ♦️ውስን ፍሬ ነው ያለው🔥🔥🔥
#
#
# 1️⃣.📍ፒያሳ ጣይቱ ሆቴል ጊቢ ውስጥ ቢሮ  ቁ04
#
# 2️⃣.📍መገናኛ መተባበር ሕንፃ 3ኛ ፎቅ ቢሮ ቁ316
#
#
# ለማዘዝ እነዚን ቁጥሮች ይጠቀሙ🔽
#                                📲 0911100302
#                                      0911887579
# 🔖
# 💬በቴሌግራም ለማዘዝ ➡️ @Akdat
#
# ቤተሰብ ይሁኑ🔽
# https://t.me/forfreemarket
#
# 🇪🇹 4FREE MARKET 🇪🇹
# Cleaned:  3 ጥቅሞችን አንድ ላይ የያዘ እያደረቀ የሚያበጥር 1 ዕቃ 3 ጥቅም ❶ ማድረቂያ , ❷ፔስትራሰትሪት መስሪያ, ❸ከርል መስርያ 3 የሙቀት መጠን ያለው ለጠንካራ ለመካከለኛ ለሉጫ ፀጉርም ሚሆን ጊዜ ቆጣቢ ፀጉርን በእሳት ከመጐዳት የሚከላከል ለልጆችም ለአዎቂ ተስማሚ የሆነ ጥራቱ አስተማማኝ እና ለአጠቃቀም ቀላል በቤትዎ እና ለፀጉር ቤት ተመራጭ ዋጋ 1,600 ብር ውስን ፍሬ ነው ያለው .ፒያሳ ጣይቱ ሆቴል ጊቢ ውስጥ ቢሮ ቁ04 .መገናኛ መተባበር ሕንፃ 3ኛ ፎቅ ቢሮ ቁ316 ለማዘዝ እነዚን ቁጥሮች ይጠቀሙ 0911100302 0911887579 በቴሌግራም ለማዘዝ ቤተሰብ ይሁኑ 4
# Tokens:   ['3', 'ጥቅሞችን', 'አንድ', 'ላይ', 'የያዘ', 'እያደረቀ', 'የሚያበጥር', '1', 'ዕቃ', '3', 'ጥቅም', '❶', 'ማድረቂያ', ',', '❷ፔስትራሰትሪት', 'መስሪያ,', '❸ከርል', 'መስርያ', '3', 'የሙቀት', 'መጠን', 'ያለው', 'ለጠንካራ', 'ለመካከለኛ', 'ለሉጫ', 'ፀጉርም', 'ሚሆን', 'ጊዜ', 'ቆጣቢ', 'ፀጉርን', 'በእሳት', 'ከመጐዳት', 'የሚከላከል', 'ለልጆችም', 'ለአዎቂ', 'ተስማሚ', 'የሆነ', 'ጥራቱ', 'አስተማማኝ', 'እና', 'ለአጠቃቀም', 'ቀላል', 'በቤትዎ', 'እና', 'ለፀጉር', 'ቤት', 'ተመራጭ', 'ዋጋ', '1,600', 'ብር', 'ውስን', 'ፍሬ', 'ነው', 'ያለው', '.ፒያሳ', 'ጣይቱ', 'ሆቴል', 'ጊቢ', 'ውስጥ', 'ቢሮ', 'ቁ04', '.መገናኛ', 'መተባበር', 'ሕንፃ', '3ኛ', 'ፎቅ', 'ቢሮ', 'ቁ316', 'ለማዘዝ', 'እነዚን', 'ቁጥሮች', 'ይጠቀሙ', '0911100302', '0911887579', 'በቴሌግራም', 'ለማዘዝ', 'ቤተሰብ', 'ይሁኑ', '4']
#
# === Channel: nevacomputer ===
# Total messages: 150
# Average tokens per message: 39.65
#
# --- Sample Message ---
# Original: Saturday discount 270k
# Cleaned:  270
# Tokens:   ['270']
#
# --- Sample Message ---
# Original: #HP PAVILION
# 🅑︎🅡︎🅐︎🅝︎🅓︎ : HP PAVILION X360
# ✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎: 14” FHD TOUCH SCREEN CONVERTIBLE
# ✨🅒︎🅟︎🅤︎: CORE I5 11th GEN 💪🏽
# ✨🅡︎🅐︎🅜︎:16Gb 𝗗𝗗𝗥4
# ✨🅢︎🅣︎🅞︎🅡︎🅐︎🅖︎: 512GB SSD
# ✨🅖︎🅡︎🅐︎🅟︎🅗︎🅘︎🅒︎🅢︎: INTEL IRIS XE GRAPHICS
# ✨🅞︎🅢︎:window 10 pro
# ✨🅑︎🅐︎🅣︎🅣︎🅔︎🅡︎🅨︎: 6HR
# ✨🅢︎🅣︎🅐︎🅣︎🅤︎🅢︎:  open box
# Price  57000 birr
# 📩@rasneva ለአጭር መልእክት
#  ይደዉሉ ☎️
# +251912759900
# +251920153333
#
# 🏢 አድራሻ: - መገናኛ ማራቶን የ ገበያ ማእከል በ ዋናው መግቢያ መሬት ላይ
# ወይንም ግራውንድ ፍሎር ብቅ ይበሉ
#  👉ነቫ ኮምፒውተር👈 መሆኑን ያረጋግጡ
#
# ድህረ ገጻችንን ይጎብኙ
# www.nevacomputer.com
#
# ቴሌግራም ቻናላችንን ይቀላቀሉ
#
# https://t.me/nevacomputer
# Cleaned:  360 14 5 11 16 𝗗𝗗𝗥4 512 10 6 57000 ለአጭር መልእክት ይደዉሉ 251912759900 251920153333 አድራሻ መገናኛ ማራቶን የ ገበያ ማእከል በ ዋናው መግቢያ መሬት ላይ ወይንም ግራውንድ ፍሎር ብቅ ይበሉ ነቫ ኮምፒውተር መሆኑን ያረጋግጡ ድህረ ገጻችንን ይጎብኙ ቴሌግራም ቻናላችንን ይቀላቀሉ
# Tokens:   ['360', '14', '5', '11', '16', '𝗗𝗗𝗥4', '512', '10', '6', '57000', 'ለአጭር', 'መልእክት', 'ይደዉሉ', '251912759900', '251920153333', 'አድራሻ', 'መገናኛ', 'ማራቶን', 'የ', 'ገበያ', 'ማእከል', 'በ', 'ዋናው', 'መግቢያ', 'መሬት', 'ላይ', 'ወይንም', 'ግራውንድ', 'ፍሎር', 'ብቅ', 'ይበሉ', 'ነቫ', 'ኮምፒውተር', 'መሆኑን', 'ያረጋግጡ', 'ድህረ', 'ገጻችንን', 'ይጎብኙ', 'ቴሌግራም', 'ቻናላችንን', 'ይቀላቀሉ']
#
# --- Sample Message ---
# Original: LENOVO X1 YOGA
# Processor: 11th‑Gen Intel Core i7‑1165G7 or i7‑1185G7 (4 cores/8 threads, 2.8–4.7 GHz Turbo, 12 MB cache)
#  • Memory: 16 GB LPDDR4x, soldered (non-upgradeable)
#  • Storage: 512 GB NVMe PCIe SSD
#  • Display: 14″ FHD+ (1920×1200) IPS, 400 nits, 10‑point multi-touch
#  • Graphics: Intel Iris Xe integrated
#  • Convertible Design: 360° hinge — use as laptop, tablet, tent, or stand
#  • Pen Included: Slim integrated stylus in chassis — ideal for note-taking or drawing
#  • Ports: 2× Thunderbolt 4 (USB4), 2× USB-A 3.2 (one Always-On), HDMI 2.0, audio jack, Kensington Nano security slot
#  • Security: TPM 2.0, fingerprint reader (integrated power button), optional IR camera + privacy shutter
#  • Build: Carbon-fiber reinforced chassis, MIL‑STD‑810H durability, ~14.99 mm thick, dimensions ~314 × 223 mm
# 📩@rasneva ለአጭር መልእክት
#  ይደዉሉ ☎️
# +251912759900
# +251920153333
# Cleaned:  1 11 711657 711857 4 8 , 2.84.7 , 12 16 4, 512 14 19201200 , 400 , 10 360 , , , 2 4 4, 2 3.2 , 2.0, , 2.0, , , 810 , 14.99 , 314 223 ለአጭር መልእክት ይደዉሉ 251912759900 251920153333
# Tokens:   ['1', '11', '711657', '711857', '4', '8', ',', '2.84.7', ',', '12', '16', '4,', '512', '14', '19201200', ',', '400', ',', '10', '360', ',', ',', ',', '2', '4', '4,', '2', '3.2', ',', '2.0,', ',', '2.0,', ',', ',', '810', ',', '14.99', ',', '314', '223', 'ለአጭር', 'መልእክት', 'ይደዉሉ', '251912759900', '251920153333']
#
# --- Sample Message ---
# Original: #EUROPE STANDARD
# 🅑︎🅡︎🅐︎🅝︎🅓︎ : ACER NITRO 5
# ✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎: 15.6” FULL HD 144HZ
# ✨🅒︎🅟︎🅤︎: CORE i7 12th generation
# ✨🅡︎🅐︎🅜︎:16Gb 𝗗𝗗𝗥5
# ✨🅢︎🅣︎🅞︎🅡︎🅐︎🅖︎: 512GB SSD
# ✨🅖︎🅡︎🅐︎🅟︎🅗︎🅘︎🅒︎🅢︎: RTX 4060 8GB
# ✨🅞︎🅢︎:window 11 pro
# ✨🅑︎🅐︎🅣︎🅣︎🅔︎🅡︎🅨︎: 4hr
# ✨🅢︎🅣︎🅐︎🅣︎🅤︎🅢︎:  brand new
# Price  159000 birr
# 📩@rasneva ለአጭር መልእክት
#  ይደዉሉ ☎️
# +251912759900
# +251920153333
#
# 🏢 አድራሻ: - መገናኛ ማራቶን የ ገበያ ማእከል በ ዋናው መግቢያ መሬት ላይ
# ወይንም ግራውንድ ፍሎር ብቅ ይበሉ
#  👉ነቫ ኮምፒውተር👈 መሆኑን ያረጋግጡ
#
# ድህረ ገጻችንን ይጎብኙ
# www.nevacomputer.com
#
# ቴሌግራም ቻናላችንን ይቀላቀሉ
#
# https://t.me/nevacomputer
# Cleaned:  5 15.6 144 7 12 16 𝗗𝗗𝗥5 512 4060 8 11 4 159000 ለአጭር መልእክት ይደዉሉ 251912759900 251920153333 አድራሻ መገናኛ ማራቶን የ ገበያ ማእከል በ ዋናው መግቢያ መሬት ላይ ወይንም ግራውንድ ፍሎር ብቅ ይበሉ ነቫ ኮምፒውተር መሆኑን ያረጋግጡ ድህረ ገጻችንን ይጎብኙ ቴሌግራም ቻናላችንን ይቀላቀሉ
# Tokens:   ['5', '15.6', '144', '7', '12', '16', '𝗗𝗗𝗥5', '512', '4060', '8', '11', '4', '159000', 'ለአጭር', 'መልእክት', 'ይደዉሉ', '251912759900', '251920153333', 'አድራሻ', 'መገናኛ', 'ማራቶን', 'የ', 'ገበያ', 'ማእከል', 'በ', 'ዋናው', 'መግቢያ', 'መሬት', 'ላይ', 'ወይንም', 'ግራውንድ', 'ፍሎር', 'ብቅ', 'ይበሉ', 'ነቫ', 'ኮምፒውተር', 'መሆኑን', 'ያረጋግጡ', 'ድህረ', 'ገጻችንን', 'ይጎብኙ', 'ቴሌግራም', 'ቻናላችንን', 'ይቀላቀሉ']
#
# --- Sample Message ---
# Original: Very portable and can do multi-task
#
# #HP ELITEBOOK 1040 G6
# 🅑︎🅡︎🅐︎🅝︎🅓︎ : HP ELITEBOOK
# ✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎: 14” convertable touch screen full HD
# ✨🅒︎🅟︎🅤︎: CORE I7 8th generation
# ✨🅡︎🅐︎🅜︎:16 GB 𝗗𝗗𝗥4
# ✨🅢︎🅣︎🅞︎🅡︎🅐︎🅖︎: 512 GB SSD
# ✨🅖︎raphics: intel uhd graphics
# ✨🅞︎🅢︎:window 11 pro
# ✨🅑︎🅐︎🅣︎🅣︎🅔︎🅡︎🅨︎: 5HR
# ✨🅢︎🅣︎🅐︎🅣︎🅤︎🅢︎:  open box
# Price  👇
# 📩@rasneva ለአጭር መልእክት
#  ይደዉሉ ☎️
# +251912759900
# +251920153333
#
# 🏢 አድራሻ: - መገናኛ ማራቶን የ ገበያ ማእከል በ ዋናው መግቢያ መሬት ላይ
# ወይንም ግራውንድ ፍሎር ብቅ ይበሉ
#  👉ነቫ ኮምፒውተር👈 መሆኑን ያረጋግጡ
#
# ድህረ ገጻችንን ይጎብኙ
# www.nevacomputer.com
#
# ቴሌግራም ቻናላችንን ይቀላቀሉ
#
# https://t.me/nevacomputer
# Cleaned:  1040 6 14 7 8 16 𝗗𝗗𝗥4 512 11 5 ለአጭር መልእክት ይደዉሉ 251912759900 251920153333 አድራሻ መገናኛ ማራቶን የ ገበያ ማእከል በ ዋናው መግቢያ መሬት ላይ ወይንም ግራውንድ ፍሎር ብቅ ይበሉ ነቫ ኮምፒውተር መሆኑን ያረጋግጡ ድህረ ገጻችንን ይጎብኙ ቴሌግራም ቻናላችንን ይቀላቀሉ
# Tokens:   ['1040', '6', '14', '7', '8', '16', '𝗗𝗗𝗥4', '512', '11', '5', 'ለአጭር', 'መልእክት', 'ይደዉሉ', '251912759900', '251920153333', 'አድራሻ', 'መገናኛ', 'ማራቶን', 'የ', 'ገበያ', 'ማእከል', 'በ', 'ዋናው', 'መግቢያ', 'መሬት', 'ላይ', 'ወይንም', 'ግራውንድ', 'ፍሎር', 'ብቅ', 'ይበሉ', 'ነቫ', 'ኮምፒውተር', 'መሆኑን', 'ያረጋግጡ', 'ድህረ', 'ገጻችንን', 'ይጎብኙ', 'ቴሌግራም', 'ቻናላችንን', 'ይቀላቀሉ']
#
# === Channel: aradabrand2 ===
# Total messages: 177
# Average tokens per message: 19.16
#
# --- Sample Message ---
# Original: ADIDAS
# NEW ARRIVAL 😍🔥🔥🔥
# Available  on hand
# Size  40 41 42 43
# Price# 3,799birr
# Contact me @naty_boy
# Phone +251977808897
# @aradabrand2 🔥🔥
#                 📌Home of BrandⓇ
# Cleaned:  40 41 42 43 3,799 _ 251977808897 2
# Tokens:   ['40', '41', '42', '43', '3,799', '_', '251977808897', '2']
#
# --- Sample Message ---
# Original: ✅ADIDAS BAD BUNNY(First quality )
# Made in Vietnam
# Price -5100birr
# Size#40#41 #42 #43
# 🔴FREE DELIVERY(ያሉበት ቦታ ያለተጨማሪ ክፍያ እናደርሳለን🏍)
# 🔴ለሱቅና ብዛት ተረካቢዎች ባስተያየት
# 📶0977808897
# 🔻🔻🔻 @Naty_boy
# አድራሻችን- ቄራ ሶፊያ ሞል ሁለተኛ ፎቅ ሱ.ቁ 216
# Cleaned:  5100 4041 42 43 ያሉበት ቦታ ያለተጨማሪ ክፍያ እናደርሳለን ለሱቅና ብዛት ተረካቢዎች ባስተያየት 0977808897 _ አድራሻችን ቄራ ሶፊያ ሞል ሁለተኛ ፎቅ ሱ.ቁ 216
# Tokens:   ['5100', '4041', '42', '43', 'ያሉበት', 'ቦታ', 'ያለተጨማሪ', 'ክፍያ', 'እናደርሳለን', 'ለሱቅና', 'ብዛት', 'ተረካቢዎች', 'ባስተያየት', '0977808897', '_', 'አድራሻችን', 'ቄራ', 'ሶፊያ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ሱ.ቁ', '216']
#
# --- Sample Message ---
# Original: ✅star WP low
# Made in Vietnam
# Master Quality Only in our Shop
# Price 3,500birr  😍🔥🔥
# Size#40,41,42,43
# 🔴FREE DELIVERY(ያሉበት ቦታ ያለተጨማሪ ክፍያ እናደርሳለን🏍)
# 🔴ለሱቅና ብዛት ተረካቢዎች ባስተያየት
# 📶0977808897
# 🔻🔻🔻 @Naty_boy
# አድራሻችን- ቄራ ሶፊያ ሞል ሁለተኛ ፎቅ ሱ.ቁ 216
# Cleaned:  3,500 40,41,42,43 ያሉበት ቦታ ያለተጨማሪ ክፍያ እናደርሳለን ለሱቅና ብዛት ተረካቢዎች ባስተያየት 0977808897 _ አድራሻችን ቄራ ሶፊያ ሞል ሁለተኛ ፎቅ ሱ.ቁ 216
# Tokens:   ['3,500', '40,41,42,43', 'ያሉበት', 'ቦታ', 'ያለተጨማሪ', 'ክፍያ', 'እናደርሳለን', 'ለሱቅና', 'ብዛት', 'ተረካቢዎች', 'ባስተያየት', '0977808897', '_', 'አድራሻችን', 'ቄራ', 'ሶፊያ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ሱ.ቁ', '216']
#
# --- Sample Message ---
# Original: ✅COOL NB (First quality )
# Made in European
# Price 4,800birr
# Size#40#41 #42 #43
# 🔴FREE DELIVERY(ያሉበት ቦታ ያለተጨማሪ ክፍያ እናደርሳለን🏍)
# 🔴ለሱቅና ብዛት ተረካቢዎች ባስተያየት
# 📶0977808897
# 🔻🔻🔻 @Naty_boy
# አድራሻችን- ቄራ ሶፊያ ሞል ሁለተኛ ፎቅ ሱ.ቁ 216
# Cleaned:  4,800 4041 42 43 ያሉበት ቦታ ያለተጨማሪ ክፍያ እናደርሳለን ለሱቅና ብዛት ተረካቢዎች ባስተያየት 0977808897 _ አድራሻችን ቄራ ሶፊያ ሞል ሁለተኛ ፎቅ ሱ.ቁ 216
# Tokens:   ['4,800', '4041', '42', '43', 'ያሉበት', 'ቦታ', 'ያለተጨማሪ', 'ክፍያ', 'እናደርሳለን', 'ለሱቅና', 'ብዛት', 'ተረካቢዎች', 'ባስተያየት', '0977808897', '_', 'አድራሻችን', 'ቄራ', 'ሶፊያ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ሱ.ቁ', '216']
#
# --- Sample Message ---
# Original: Chekich
# NEW ARRIVAL 😍🔥🔥🔥
# Available  on hand
# Size  40 41 42 43
# Price# birr
# Contact me @naty_boy
# Phone +251977808897
# @aradabrand2 🔥🔥
#                 📌Home of BrandⓇ
#
# 📌አድራሻ - አዲስ አበባ, ቄራ ፡ ሶፊያ ሞል 2ኛ ፍሎር ላይ፡ የሱቅ ቁ.216
# Cleaned:  40 41 42 43 _ 251977808897 2 አድራሻ አዲስ አበባ, ቄራ ሶፊያ ሞል 2ኛ ፍሎር ላይ የሱቅ ቁ.216
# Tokens:   ['40', '41', '42', '43', '_', '251977808897', '2', 'አድራሻ', 'አዲስ', 'አበባ,', 'ቄራ', 'ሶፊያ', 'ሞል', '2ኛ', 'ፍሎር', 'ላይ', 'የሱቅ', 'ቁ.216']
#
# === Channel: Fashiontera ===
# Total messages: 192
# Average tokens per message: 18.52
#
# --- Sample Message ---
# Original: 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan 1  Low Travis scott
# Made in Vietnam
# Size  #40,42,43
# Price 2600
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Cleaned:  1 40,42,43 2600 5266 ስልክ 251945355266 ፋሽን ተራ አድራሻ አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ ቢሮ ቁጥር 205
# Tokens:   ['1', '40,42,43', '2600', '5266', 'ስልክ', '251945355266', 'ፋሽን', 'ተራ', 'አድራሻ', 'አዲስ', 'አበባ', ',ጦር', 'ሀይሎች', 'ድሪም', 'ታወር', '2ተኛ', 'ፎቅ', 'ቢሮ', 'ቁጥር', '205']
#
# --- Sample Message ---
# Original: 〰️〰️〰️〰️〰️〰️〰️
# All star
# Made in Vietnam
# Size 43
# Price 2500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Cleaned:  43 2500 5266 ስልክ 251945355266 ፋሽን ተራ አድራሻ አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ ቢሮ ቁጥር 205
# Tokens:   ['43', '2500', '5266', 'ስልክ', '251945355266', 'ፋሽን', 'ተራ', 'አድራሻ', 'አዲስ', 'አበባ', ',ጦር', 'ሀይሎች', 'ድሪም', 'ታወር', '2ተኛ', 'ፎቅ', 'ቢሮ', 'ቁጥር', '205']
#
# --- Sample Message ---
# Original: 〰️〰️〰️〰️〰️〰️〰️
# All star Leather
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size   38,39
# Price  2900
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Cleaned:  38,39 2900 5266 ስልክ 251945355266 ፋሽን ተራ አድራሻ አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ ቢሮ ቁጥር 205
# Tokens:   ['38,39', '2900', '5266', 'ስልክ', '251945355266', 'ፋሽን', 'ተራ', 'አድራሻ', 'አዲስ', 'አበባ', ',ጦር', 'ሀይሎች', 'ድሪም', 'ታወር', '2ተኛ', 'ፎቅ', 'ቢሮ', 'ቁጥር', '205']
#
# --- Sample Message ---
# Original: 〰️〰️〰️〰️〰️〰️〰️
# Jordan low
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    40,41
# Price  3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Cleaned:  40,41 3500 5266 ስልክ 251945355266 ፋሽን ተራ አድራሻ አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ ቢሮ ቁጥር 205
# Tokens:   ['40,41', '3500', '5266', 'ስልክ', '251945355266', 'ፋሽን', 'ተራ', 'አድራሻ', 'አዲስ', 'አበባ', ',ጦር', 'ሀይሎች', 'ድሪም', 'ታወር', '2ተኛ', 'ፎቅ', 'ቢሮ', 'ቁጥር', '205']
#
# --- Sample Message ---
# Original: 〰️〰️〰️〰️〰️〰️〰️
# Skechers
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size 40,41,42,43
# Price  2800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Cleaned:  40,41,42,43 2800 5266 ስልክ 251945355266 ፋሽን ተራ አድራሻ አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ ቢሮ ቁጥር 205
# Tokens:   ['40,41,42,43', '2800', '5266', 'ስልክ', '251945355266', 'ፋሽን', 'ተራ', 'አድራሻ', 'አዲስ', 'አበባ', ',ጦር', 'ሀይሎች', 'ድሪም', 'ታወር', '2ተኛ', 'ፎቅ', 'ቢሮ', 'ቁጥር', '205']
#
# === Channel: Shewabrand ===
# Total messages: 424
# Average tokens per message: 23.53
#
# --- Sample Message ---
# Original: 🔥 adidas  T-shirt 🔥
#
# Available on hand
# Best Quality
# Size  M L XL 2XL
# Phone +251987336458
# 0924209500
# SEWA BRAND
# ሌላም ተጨማሪ ከለርች አሉ
# Cleaned:  2 251987336458 0924209500 ሌላም ተጨማሪ ከለርች አሉ
# Tokens:   ['2', '251987336458', '0924209500', 'ሌላም', 'ተጨማሪ', 'ከለርች', 'አሉ']
#
# --- Sample Message ---
# Original: SKECHERS PERFORMANCE
# Size 36#37#38#39
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# Cleaned:  36373839 አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን የቴሌግራም ቻናላችንን ይቀላቀሉ የቤት ቁጥር 109 እና 110 በ 2 አዋሩን 0987336458 0948595409 ይደውሉልን
# Tokens:   ['36373839', 'አድራሻ', 'ድሬዳዋ', 'አሸዋ', 'ሚና', 'ህንፃ', '1ኛ', 'ፎቅ', 'ላይ', 'እንገኛለን', 'የቴሌግራም', 'ቻናላችንን', 'ይቀላቀሉ', 'የቤት', 'ቁጥር', '109', 'እና', '110', 'በ', '2', 'አዋሩን', '0987336458', '0948595409', 'ይደውሉልን']
#
# --- Sample Message ---
# Original: SKECHERS Archfit
# Size 40#41#42#43
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# Cleaned:  40414243 አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን የቴሌግራም ቻናላችንን ይቀላቀሉ የቤት ቁጥር 109 እና 110 በ 2 አዋሩን 0987336458 0948595409 ይደውሉልን
# Tokens:   ['40414243', 'አድራሻ', 'ድሬዳዋ', 'አሸዋ', 'ሚና', 'ህንፃ', '1ኛ', 'ፎቅ', 'ላይ', 'እንገኛለን', 'የቴሌግራም', 'ቻናላችንን', 'ይቀላቀሉ', 'የቤት', 'ቁጥር', '109', 'እና', '110', 'በ', '2', 'አዋሩን', '0987336458', '0948595409', 'ይደውሉልን']
#
# --- Sample Message ---
# Original: ALLSTAR CONVERS lezear
# Size 36#37#38#39
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# Cleaned:  36373839 አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን የቴሌግራም ቻናላችንን ይቀላቀሉ የቤት ቁጥር 109 እና 110 በ 2 አዋሩን 0987336458 0948595409 ይደውሉልን
# Tokens:   ['36373839', 'አድራሻ', 'ድሬዳዋ', 'አሸዋ', 'ሚና', 'ህንፃ', '1ኛ', 'ፎቅ', 'ላይ', 'እንገኛለን', 'የቴሌግራም', 'ቻናላችንን', 'ይቀላቀሉ', 'የቤት', 'ቁጥር', '109', 'እና', '110', 'በ', '2', 'አዋሩን', '0987336458', '0948595409', 'ይደውሉልን']
#
# --- Sample Message ---
# Original: NIKE   PHANTOM ORIGINAL 💯
# Size 40#41#42#43#44
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# Cleaned:  4041424344 አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን የቴሌግራም ቻናላችንን ይቀላቀሉ የቤት ቁጥር 109 እና 110 በ 2 አዋሩን 0987336458 0948595409 ይደውሉልን
# Tokens:   ['4041424344', 'አድራሻ', 'ድሬዳዋ', 'አሸዋ', 'ሚና', 'ህንፃ', '1ኛ', 'ፎቅ', 'ላይ', 'እንገኛለን', 'የቴሌግራም', 'ቻናላችንን', 'ይቀላቀሉ', 'የቤት', 'ቁጥር', '109', 'እና', '110', 'በ', '2', 'አዋሩን', '0987336458', '0948595409', 'ይደውሉልን']
